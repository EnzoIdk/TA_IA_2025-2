# %% [markdown]
# # TRABAJO ACADÉMICO INTELIGENCIA ARTIFICIAL 2025-2

# %% [markdown]
# ## Librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carga de datos

# %% [markdown]
# Descripción de los datos:
#
# 1)
#
# 2)
#
# 3)

# %%
INPUT_FILE_NAME="datos.csv"

# %%
dataset = pd.read_csv(INPUT_FILE_NAME)
